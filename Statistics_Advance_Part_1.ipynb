# %% [markdown]
# ## Statistics Advance Part 1

# %% [markdown]
# 1 What is a random variable in probability theory?
# -  In probability theory, a random variable is a fundamental concept used to describe the outcomes of a random experiment in numerical terms. It is a function that maps each possible outcome in a sample space to a real number. This means that while an experiment might produce outcomes that are not numbers (such as flipping a coin and getting "heads" or "tails"), a random variable allows us to represent these outcomes with numbers so we can apply mathematical tools to study them.
#
# -  There are two main types of random variables: discrete and continuous. A discrete random variable takes on a countable number of distinct values. For example, if we roll a six-sided die, we can define a random variable
# 𝑋
# X that represents the number shown on the die. The possible values of
# 𝑋
# X are 1, 2, 3, 4, 5, and 6—clearly a finite and countable set. In contrast, a continuous random variable can take on an infinite number of possible values within a given interval. For example, if we measure the amount of time it takes for a person to complete a task, the time could be any positive real number, such as 2.5 seconds, 2.501 seconds, or 2.5001 seconds, making it continuous.
#
# -  Random variables are useful because they allow us to compute probabilities for different outcomes and to summarize the behavior of random processes using numerical measures such as the expected value (which gives a long-run average outcome), variance (which measures the spread or uncertainty), and probability distributions (which describe how likely different values are). For example, in a game of chance, a random variable can be used to represent a player’s score, and we can then use that to calculate the probability of winning or the average score over many rounds.

# %% [markdown]
# 2 What are the types of random variables?
# -  There are two main types of random variables in probability theory: discrete and continuous. These types are based on the kinds of values the random variable can take.
#
# 1. Discrete Random Variable
# A discrete random variable is one that can take on a finite or countably infinite number of distinct values. These values are usually whole numbers.
# -  Characteristics:
#  - Values are separated and distinct (not continuous).
#
#  -  Commonly arise from counting things.
#
# -  Examples:
#  -  Number of heads when flipping a coin 3 times (0, 1, 2, or 3).
#
#  -  Number of students present in class.
#
#  -  The result of rolling a die (1 to 6).
#
#  -  Represented by:
# A probability mass function (PMF), which gives the probability of each possible value.
#
# 2. Continuous Random Variable
# A continuous random variable is one that can take on any value within a given range or interval. These values are uncountable and can include decimals and irrational numbers.
#
# -  Characteristics:
# Takes infinitely many values within a range.
#
#  -  Usually represent measurements.
#
# -  Examples:
#  -  Height of students in a classroom.
#
#  - Time taken to run a race.
#
#  -  Temperature during the day.
#
# -  Represented by:
#  -  A probability density function (PDF), where probabilities are found over intervals (e.g., the probability that a value falls between 1.5 and 2.5).

# %% [markdown]
# 3 What is the difference between discrete and continuous distributions?
# -  The difference between discrete and continuous distributions lies in the type of data they describe and how probabilities are assigned to outcomes. A discrete distribution deals with discrete random variables, which can take only specific, countable values such as whole numbers. These distributions assign probabilities to individual outcomes, and the sum of all these probabilities is equal to 1. A common example of a discrete distribution is the binomial distribution, which models the number of successes in a fixed number of trials, like flipping a coin 10 times and counting the number of heads. Other examples include the Poisson distribution (used to count events in a fixed time or space) and the geometric distribution (which models the number of trials until the first success). In discrete distributions, probabilities are calculated using a Probability Mass Function (PMF).
#
# -  In contrast, a continuous distribution describes the behavior of continuous random variables, which can take any value within a certain range, including decimals and irrational numbers. Instead of assigning probability to individual values (which would always be zero), continuous distributions assign probabilities to intervals of values using a Probability Density Function (PDF). For example, the normal distribution—often seen in real-life phenomena like height, weight, or test scores—uses a smooth bell-shaped curve to represent the distribution of values. Other examples include the uniform distribution, where all values in a range are equally likely, and the exponential distribution, which models the time between events in a Poisson process. The probability that a continuous variable falls within a certain interval is found by calculating the area under the curve of the PDF over that interval.

# %% [markdown]
# 4 What are probability distribution functions (PDF)?
# -  A Probability Distribution Function (PDF) is a mathematical function used to describe the likelihood of a continuous random variable taking values within a certain range. Unlike discrete variables, where specific outcomes can have a non-zero probability, continuous random variables can take on infinitely many values within an interval, so the probability of the variable taking any exact value is always zero. Instead, the PDF helps determine the probability that the variable falls within a range of values by calculating the area under the curve of the function over that interval. The PDF itself must always be non-negative, and the total area under its curve must equal 1, since the total probability across all possible outcomes must be 100%. For example, in a normal distribution, the PDF has a bell-shaped curve that shows how values cluster around the mean, while in a uniform distribution, the PDF is flat, indicating all values within the range are equally likely. PDFs are essential in probability and statistics because they allow us to model real-world measurements such as height, weight, time, and many other continuous phenomena, and to calculate probabilities in those contexts accurately.

# %% [markdown]
# 5 How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# -  The Cumulative Distribution Function (CDF) and the Probability Distribution Function (PDF) are both used to describe the behavior of a random variable, but they serve different purposes and represent probability in different ways.
#
# -  A Probability Distribution Function (PDF) is used specifically for continuous random variables and describes the relative likelihood of the variable taking on a specific value within a range. It gives the density of probability at each point, but not the actual probability at any single point, since the probability of any exact value in a continuous distribution is zero. Instead, the PDF helps calculate the probability that the variable falls within an interval, by integrating the function over that interval. In simple terms, the PDF shows how "dense" the probability is around each value.
#
# -  On the other hand, a Cumulative Distribution Function (CDF) is more general—it applies to both discrete and continuous random variables. The CDF gives the cumulative probability that a random variable will take a value less than or equal to a specific number. Mathematically, for a continuous random variable
# 𝑋
# X, the CDF at a point
# 𝑥
# x is defined as:
#
# ![image.png](data:image/png;base64,...)
#
# -  This means the CDF is the integral (or accumulated area) under the PDF curve up to the point
# 𝑥
# x. While the PDF tells us about probability density, the CDF tells us the total probability up to a certain value.

# %% [markdown]
# 6 What is a discrete uniform distribution?
# -  A discrete uniform distribution is a probability distribution in which a finite number of distinct outcomes are equally likely to occur. This means that each value in the set of possible outcomes has the same probability of happening. The distribution is called "discrete" because the outcomes are countable, and "uniform" because each outcome has an equal chance of occurring. Mathematically, if a random variable
# 𝑋
# X follows a discrete uniform distribution over
# 𝑛
# n possible outcomes, the probability of each outcome is simply
# 1
# 𝑛
# n
# 1
# ​
#  . For example, when rolling a fair 6-sided die, the outcomes (1, 2, 3, 4, 5, 6) are all equally likely, each with a probability of
# 1
# 6
# 6
# 1
# ​
#  . Other examples include randomly selecting a card from a shuffled deck, where each card has an equal chance of being picked, or randomly choosing a number from a set of integers. This distribution is commonly used to model situations where every outcome is equally likely, making it a fundamental concept in probability and statistics.

# %% [markdown]
# 7 What are the key properties of a Bernoulli distribution?
# -  The Bernoulli distribution is a probability distribution that models experiments with exactly two possible outcomes, typically labeled as "success" (1) or "failure" (0). It is characterized by a single parameter,
# 𝑝
# p, which represents the probability of success. The probability of failure is therefore
# 1
# −
# 𝑝
# 1−p. The Bernoulli distribution is discrete, with a probability mass function (PMF) that assigns
# 𝑝
# p to the outcome of success (1) and
# 1
# −
# 𝑝
# 1−p to the outcome of failure (0). The mean or expected value of a Bernoulli random variable is
# 𝑝
# p, indicating the probability of success, while its variance is
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p), which measures the variability around the mean. The Bernoulli distribution is a special case of the Binomial distribution when there is only one trial, making it foundational for understanding binomial experiments. It is defined on the set
# {
# 0
# ,
# 1
# }
# {0,1}, meaning that the random variable can only take these two values, and it is memoryless, meaning the probability of success in any trial is independent of previous outcomes. A classic example of a Bernoulli distribution is flipping a fair coin, where the probability of getting heads (success) is
# 𝑝
# =
# 0.5
# p=0.5, and the probability of getting tails (failure) is
# 1
# −
# 𝑝
# =
# 0.5
# 1−p=0.5.

# %% [markdown]
# 8 What is the binomial distribution, and how is it used in probability?
# -  The Binomial distribution is a discrete probability distribution used to model the number of successes in a fixed number of independent trials, where each trial has two possible outcomes: "success" or "failure." It is defined by two parameters:
# 𝑛
# n, the number of trials, and
# 𝑝
# p, the probability of success in each trial. The distribution is appropriate when the trials are independent, meaning the outcome of one trial does not affect the others, and the probability of success remains constant across all trials. The random variable in a Binomial distribution represents the total number of successes observed in
# 𝑛
# n trials. The Probability Mass Function (PMF) for a Binomial distribution is given by the formula
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#  , where
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ) is the binomial coefficient, which represents the number of ways to choose
# 𝑘
# k successes from
# 𝑛
# n trials. This distribution is commonly used in scenarios such as flipping a coin multiple times, determining the number of heads in a series of flips, or calculating the probability of a certain number of successes in repeated experiments like quality control testing. The Binomial distribution helps estimate probabilities for different numbers of successes and provides valuable insight in various fields such as statistics, engineering, and economics.

# %% [markdown]
# 9 What is the Poisson distribution and where is it applied?
# -  The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time or space, given that these events happen with a constant average rate and are independent of each other. It is particularly useful for modeling rare or infrequent events, such as the number of accidents at an intersection in a day, the number of customer arrivals at a service center per hour, or the number of phone calls received by a call center in a given time period. The distribution is defined by a single parameter,
# 𝜆
# λ (lambda), which represents the average rate of occurrence. The random variable in a Poisson distribution represents the count of events, which can take non-negative integer values. The Poisson probability mass function (PMF) gives the probability of observing exactly
# 𝑘
# k events in the interval, and it is expressed as
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝜆
# 𝑘
# 𝑒
# −
# 𝜆
# 𝑘
# !
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#  .
# ​ The Poisson distribution is widely applied in fields such as telecommunications, traffic and transportation, biology, and engineering to model random events that occur at a constant rate over time or space. For example, it can be used to estimate the number of accidents at a specific intersection, the number of defects in a manufacturing process, or the number of rare events like genetic mutations or system failures.

# %% [markdown]
# 10 What is a continuous uniform distribution?
# -  A continuous uniform distribution is a probability distribution in which every outcome within a specified continuous range is equally likely to occur. It is defined over an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b], where
# 𝑎
# a is the minimum value and
# 𝑏
# b is the maximum value. The probability density function (PDF) of a continuous uniform distribution is constant throughout the interval, and the probability of any value within this range is the same. The PDF is given by
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# f(x)=
# b−a
# 1
# ​
#   for
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# a≤x≤b, meaning that the distribution has a constant height over the interval. The mean of the distribution is the midpoint of the interval,
# 𝑎
# +
# 𝑏
# 2
# 2
# a+b
# ​
#  , and its variance is
# (
# 𝑏
# −
# 𝑎
# )
# 2
# 12
# 12
# (b−a)
# 2
# .
# ​
#  This distribution is used in situations where every outcome in a range is equally probable, such as generating random numbers, simulating fair processes, or selecting a random point on a line segment. The continuous uniform distribution is a simple yet useful model for scenarios where all outcomes within a specific interval are presumed to have an equal chance of occurring.

# %% [markdown]
# 11 What are the characteristics of a normal distribution?
# -  The normal distribution, also known as the Gaussian distribution, is one of the most important and widely used probability distributions in statistics, characterized by a bell-shaped curve that is symmetric around its mean. This symmetry means that the mean, median, and mode of the distribution all coincide at the center of the curve. The distribution is defined by two parameters: the mean (
# 𝜇
# μ), which represents the center of the distribution, and the standard deviation (
# 𝜎
# σ), which measures the spread of the data. A smaller standard deviation results in a steeper, narrower curve, while a larger standard deviation creates a flatter, wider curve. The normal distribution is commonly used to model real-world phenomena, as many natural and human-made processes tend to follow this pattern, such as heights, test scores, and measurement errors. Its probability density function (PDF) is bell-shaped, with the highest probability density at the mean, and the likelihood of values decreases as you move further away from the mean. The normal distribution is essential in statistics because of its properties and its foundational role in inferential statistics, such as hypothesis testing and confidence intervals.

# %% [markdown]
# 12 What is the standard normal distribution, and why is it important?
# -  The standard normal distribution is a special case of the normal distribution with a mean of 0 and a standard deviation of 1. It serves as a reference distribution for comparing other normal distributions and simplifies statistical calculations. The probability density function (PDF) of the standard normal distribution is bell-shaped and symmetric around 0, with its formula given by
# 𝑓
# (
# 𝑧
# )
# =
# 1
# 2
# 𝜋
# 𝑒
# −
# 𝑧
# 2
# 2
# f(z)=
# 2π
# ​
#
# -  1
# ​
#  e
# −
# 2
# z
# 2
#
# ​
#
#  -   where
# 𝑧
# z is the standard normal variable. A key feature of the standard normal distribution is the Z-score, which measures how many standard deviations a data point is from the mean. This allows any normal distribution to be transformed into the standard normal distribution, making it easier to use Z-tables for calculating probabilities and percentiles. The standard normal distribution is critical in hypothesis testing, confidence intervals, and other statistical methods, as it provides a universal comparison point for different normal distributions. Its fixed parameters make it essential for simplifying complex problems and providing a standard framework for statistical analysis.

# %% [markdown]
# 13 What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# -  The Central Limit Theorem (CLT) is a fundamental principle in statistics that states that the distribution of the sample mean will approach a normal distribution as the sample size increases, regardless of the shape of the population distribution. This is true as long as the samples are independent and identically distributed. Essentially, the CLT ensures that, with a sufficiently large sample size (typically
# 𝑛
# ≥
# 30
# n≥30), the distribution of sample means will be approximately normal, even if the original population distribution is not. The mean of this sampling distribution will be equal to the population mean, and its standard deviation will be the population standard deviation divided by the square root of the sample size. The CLT is critical in statistics because it forms the basis for many inferential statistical methods, such as hypothesis testing and confidence intervals. It allows statisticians to apply normal distribution-based techniques to estimate population parameters and make predictions, even when the underlying population is not normally distributed. This makes the CLT essential for making reliable inferences about populations using sample data.

# %% [markdown]
# 14 How does the Central Limit Theorem relate to the normal distribution?
# -  The Central Limit Theorem (CLT) is directly related to the normal distribution because it explains why the sampling distribution of the sample mean approaches a normal distribution, regardless of the shape of the population distribution, as the sample size increases. Essentially, the CLT bridges the gap between arbitrary population distributions and the normal distribution, making the normal distribution a powerful tool for statistical inference.
#
# -  Here's how the CLT relates to the normal distribution:
#
#  - Convergence to Normality:
# The CLT states that no matter the original shape of the population distribution (whether it's skewed, uniform, or any other form), the distribution of the sample means will become more normal as the sample size increases. In other words, as the sample size
# 𝑛
# n gets larger, the sampling distribution of the sample mean will approximate a normal distribution, even if the population itself is not normal.
#
#  -  Normal Approximation for Large Samples:
# As long as the sample size is large enough (typically
# 𝑛
# ≥
# 30
# n≥30), the sampling distribution of the mean will resemble a normal distribution. This is significant because it allows statisticians to apply the properties of the normal distribution to data from non-normal populations when making inferences.
#
#  -  Mean and Standard Deviation of the Sampling Distribution:
# According to the CLT, the sampling distribution of the sample mean will have a mean equal to the population mean (
# 𝜇
# μ) and a standard deviation (known as the standard error) equal to
# 𝜎
# 𝑛
# n
# ​
#
#  -  σ
# ​
#  , where
# 𝜎
# σ is the population standard deviation and
# 𝑛
# n is the sample size. This means that as the sample size increases, the standard deviation of the sampling distribution becomes smaller, making the sample mean a more precise estimator of the population mean.
#
#  -  Enabling Normal Distribution-based Inference:
# Because the CLT ensures that the distribution of sample means approximates a normal distribution for large samples, it allows statisticians to use Z-scores and t-tests, which rely on the normal distribution, to make inferences about population parameters. This is especially useful when dealing with unknown population distributions, as the CLT makes the normal distribution applicable for hypothesis testing, confidence intervals, and other statistical methods.

# %% [markdown]
# 15  What is the application of Z statistics in hypothesis testing?
# -  Z-statistics are widely used in hypothesis testing to assess whether sample data significantly deviates from a hypothesized population parameter. The Z-statistic measures how far a sample statistic, such as the sample mean, is from the population parameter in terms of standard deviations. It is most useful when the sample size is large (
# 𝑛
# ≥
# 30
# n≥30) and the population standard deviation is known. Z-tests are commonly applied in testing hypotheses about population means, where the Z-statistic for the sample mean is calculated and compared to a critical value from the standard normal distribution to determine if the observed difference is statistically significant. Z-statistics are also used in testing population proportions, where the sample proportion is tested against a hypothesized population proportion. In hypothesis testing, the Z-statistic helps to standardize results, allowing for comparisons across different data sets and enabling the use of Z-tables to find critical values and p-values. Z-statistics are particularly valuable for large sample sizes, as they provide a reliable framework for making decisions based on the normal distribution. In summary, Z-statistics play a crucial role in hypothesis testing by allowing researchers to assess the significance of sample data, standardize test results, and make informed decisions about the validity of null hypotheses.

# %% [markdown]
# 16  How do you calculate a Z-score, and what does it represent?
# -  A Z-score is a statistical measure that indicates how many standard deviations a data point is away from the mean of a distribution. It is calculated by subtracting the mean (
# 𝜇
# μ) of the data set from the individual data point (
# 𝑋
# X) and then dividing the result by the standard deviation (
# 𝜎
# σ). The formula is
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#  . A Z-score of 0 means the data point is exactly at the mean, while a positive Z-score indicates the value is above the mean, and a negative Z-score indicates it is below the mean. The magnitude of the Z-score tells you how far the data point is from the mean in terms of standard deviations. For example, a Z-score of 2 means the data point is two standard deviations above the mean, and a Z-score of -3 means it is three standard deviations below the mean. Z-scores are useful in comparing values across different distributions and are also critical in hypothesis testing, where they help assess the rarity or extremity of a data point relative to the population.

# %% [markdown]
# 17 What are point estimates and interval estimates in statistics?
# -  In statistics, point estimates and interval estimates are two types of estimates used to infer unknown population parameters based on sample data. They are essential tools in inferential statistics, allowing researchers to make inferences about a population from a sample.
#
# -  Point Estimate:
# A point estimate is a single value used to estimate an unknown population parameter. It is derived from sample data and serves as the best guess for the true parameter. For example, the sample mean (
# 𝑋
# ˉ
# X
# ˉ
#  ) is often used as a point estimate for the population mean (
# 𝜇
# μ), and the sample proportion (
# 𝑝
# ^
# p
# ^
# ​
#  ) is used as a point estimate for the population proportion (
# 𝑝
# p).
#
# -  The main characteristic of a point estimate is that it provides a specific value, but it does not offer any information about the possible variability or uncertainty of the estimate. While point estimates are simple and easy to calculate, they do not reflect the degree of confidence in the estimate, which is a limitation when making decisions or drawing conclusions.
#
# -  Interval Estimate:
# An interval estimate provides a range of values within which the true population parameter is likely to lie, along with a level of confidence. This range is usually expressed as a confidence interval, which is constructed around the point estimate. For example, a 95% confidence interval for the population mean might be expressed as
# [
# 𝑋
# ˉ
# −
# 𝐸
# ,
# 𝑋
# ˉ
# +
# 𝐸
# ]
# [
# X
# ˉ
#  −E,
# X
# ˉ
#  +E], where
# 𝑋
# ˉ
# X
# ˉ
#   is the sample mean and
# 𝐸
# E is the margin of error.
#
# -  The interval estimate provides more information than a point estimate because it reflects the uncertainty in the estimate and gives a range of plausible values for the population parameter. The confidence level (e.g., 95%, 99%) indicates the probability that the interval contains the true parameter. A higher confidence level results in a wider interval, reflecting greater uncertainty.

# %% [markdown]
# 18 What is the significance of confidence intervals in statistical analysis?
# -  Confidence intervals play a crucial role in statistical analysis because they provide a range of values within which a population parameter (such as a population mean or proportion) is likely to fall, based on sample data. They offer more than just a point estimate by quantifying the uncertainty and variability inherent in sample-based estimations. The significance of confidence intervals lies in their ability to give both an estimate and a measure of the precision of that estimate.
#
# -  Key Points on the Significance of Confidence Intervals:
# Uncertainty Measurement:
# Confidence intervals allow researchers to express the uncertainty of an estimate. Rather than providing a single value (point estimate) and assuming it is the true value, a confidence interval acknowledges that the estimate is subject to variation. The interval gives a range of plausible values for the population parameter, showing the precision of the estimate.
#
# -  Interpretation of Confidence Levels:
# The confidence level (e.g., 95%, 99%) associated with a confidence interval indicates how confident we are that the interval contains the true population parameter. For example, a 95% confidence interval means that if we were to take many samples and compute a confidence interval for each, about 95% of those intervals would contain the true parameter. This gives a sense of reliability to the interval.
#
# -  Decision Making:
# Confidence intervals are crucial in decision-making processes because they provide a range of possible values, allowing analysts to make informed judgments about the data. For example, in hypothesis testing, if a confidence interval does not contain the hypothesized value of a parameter, it provides evidence to reject the null hypothesis.
#
# -  Assessing Precision:
# The width of a confidence interval reflects the precision of the estimate. A narrower confidence interval suggests a more precise estimate, while a wider interval indicates greater uncertainty. The width depends on factors like sample size and variability in the data. Larger sample sizes generally result in narrower intervals, providing more precise estimates.
#
# -  Generalization to the Population:
# Confidence intervals allow researchers to generalize their findings from the sample to the broader population. By providing a plausible range of values for a population parameter, confidence intervals help in making conclusions about the entire population based on a sample.
#
# -  Comparison of Estimates:
# Confidence intervals are often used to compare estimates across different groups or conditions. For example, comparing the confidence intervals for the means of two groups can help determine whether their means are significantly different. If the intervals overlap, the difference between the groups may not be statistically significant.
#
# -  Communication of Results:
# Confidence intervals help communicate the reliability and uncertainty of research findings to a wider audience, such as policymakers or other stakeholders. They provide a more complete picture than point estimates, showing the range of possible values for the parameter of interest.

# %% [markdown]
# 19 What is the relationship between a Z-score and a confidence interval?
# -  The Z-score and confidence interval are closely related in statistical analysis, particularly when constructing intervals to estimate population parameters. The Z-score represents how many standard deviations a sample statistic (such as a sample mean) is from the population mean, and it is a key component in calculating confidence intervals. Specifically, the Z-score is used to determine the critical value that defines the range of the confidence interval. For example, in a 95% confidence interval, the Z-score corresponding to this confidence level is typically 1.96, meaning the sample mean is expected to lie within 1.96 standard deviations of the population mean in 95% of samples. The formula for constructing a confidence interval involves adding and subtracting the product of the Z-score and the standard error from the sample statistic. This range reflects where the true population parameter is likely to fall with a given level of confidence. In summary, the Z-score provides the necessary critical value to calculate the boundaries of a confidence interval, helping to quantify the uncertainty and precision of an estimate.

# %% [markdown]
# 20 How are Z-scores used to compare different distributions?
# -  Z-scores are a valuable tool for comparing different distributions because they standardize data points, allowing for meaningful comparisons across distributions with varying scales, units, or shapes. By converting raw values into standard deviations from the mean, Z-scores provide a common scale for evaluation, making it easier to assess how far a data point is from the average, regardless of the distribution’s original units or standard deviation. For example, when comparing scores from two exams with different means and standard deviations, converting the raw scores into Z-scores enables a direct comparison of how a student performed relative to the class average in both cases. Z-scores are also helpful when combining data from different sources or measuring variables on different scales, such as comparing heights measured in centimeters and inches. Additionally, Z-scores are used to identify outliers, as values far from 0 (typically above +3 or below -3) indicate unusual data points. Overall, Z-scores provide a standardized way to compare data across different distributions, assess relative performance, and make cross-distribution comparisons easier to interpret.

# %% [markdown]
# 21 What are the assumptions for applying the Central Limit Theorem?
# -  The Central Limit Theorem (CLT) relies on several assumptions for it to apply effectively. First, the sample must be randomly selected, ensuring that every member of the population has an equal chance of being chosen, which helps avoid biases. Additionally, the observations in the sample must be independent of each other, meaning that the value of one observation does not influence another. The sample size also plays a crucial role; while the CLT holds for any sample size, larger samples (typically
# 𝑛
# ≥
# 30
# n≥30) are preferred to ensure that the sample mean approximates a normal distribution. Furthermore, the population from which the sample is drawn should have a finite variance, as infinite variance can undermine the application of the CLT. Finally, while the original population distribution does not need to be normal, if it is highly skewed or contains extreme outliers, a larger sample size may be required to approximate normality. When these conditions are met, the CLT ensures that the distribution of the sample mean will approach a normal distribution as the sample size increases, even if the population itself is not normally distributed.

# %% [markdown]
# 22 What is the concept of expected value in a probability distribution?
# -  The expected value in a probability distribution represents the long-run average outcome of a random variable. It is a measure of central tendency that gives an idea of what one would expect, on average, if an experiment or process were repeated many times. For discrete random variables, the expected value is calculated by multiplying each possible outcome by its probability and summing these products. In the case of continuous random variables, the expected value is determined by integrating the product of the variable's probability density function and the variable itself over all possible values. The expected value is significant because it provides insight into the center or average of the probability distribution, helping in decision-making under uncertainty. It is widely used in fields like economics, insurance, and game theory to assess the average payoff or cost, even when individual outcomes are uncertain. For example, in the case of rolling a fair six-sided die, the expected value would be 3.5, indicating that over many rolls, the average outcome tends to this value.

# %% [markdown]
# 23 How does a probability distribution relate to the expected outcome of a random variable?
# -   A probability distribution describes the likelihood of different outcomes for a random variable. It provides the framework for calculating the expected outcome (or expected value) of that random variable. The expected value is essentially a weighted average of all possible outcomes, where each outcome is weighted by its probability.
#
# -  The relationship between a probability distribution and the expected outcome lies in the fact that the probability distribution outlines all the potential outcomes and their associated probabilities. The expected value is derived from this distribution by multiplying each possible outcome by its corresponding probability and then summing the results. This gives a single value that represents the "average" or most likely outcome, considering all the probabilities in the distribution.
#
# -  For example, in the case of a discrete probability distribution, where the random variable can take on specific values, the expected value is computed by summing the products of each outcome and its probability. In a continuous probability distribution, the expected value is calculated using an integral, where the values of the random variable are multiplied by their probability density function over a continuous range.
#
# -  In essence, the probability distribution provides the necessary information about the likelihood of each outcome, and the expected value is a summary statistic that uses this information to give an estimate of the average or "typical" result one can expect from a random variable. It helps translate the distribution into a more meaningful, singular value that represents the central tendency of the random variable's possible outcomes.

# %% [markdown]
# # ***Practical***

# %% [markdown]
# 1 Write a Python program to generate a random variable and display its value.

# %%
import random

# Generate a random integer between 1 and 100
random_variable = random.randint(1, 100)

# Display the value of the random variable
print("The value of the random variable is:", random_variable)
# Out:
# The value of the random variable is: 76

# %% [markdown]
# 2 Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of the uniform distribution
low = 1  # lowest value
high = 6  # highest value

# Generate a discrete uniform distribution
x = np.arange(low, high + 1)  # Possible outcomes (1, 2, 3, 4, 5, 6)
probabilities = np.ones_like(x) / len(x)  # Each outcome has equal probability

# Plot the PMF
plt.bar(x, probabilities, width=0.8, align='center', color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.title('Probability Mass Function (PMF) of Discrete Uniform Distribution')

# Show the plot
plt.xticks(x)  # Set x-ticks to match the outcomes
plt.show()

# %% [markdown]
# 3 Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pdf(p, x):
    """
    Calculate the Probability Distribution Function (PDF) of a Bernoulli distribution.

    Parameters:
    p (float): Probability of success (0 <= p <= 1).
    x (int): Outcome (either 0 or 1).

    Returns:
    float: Probability of the outcome x (either P(X = 0) or P(X = 1)).
    """
    if x not in [0, 1]:
        raise ValueError("x must be either 0 or 1 for a Bernoulli distribution.")

    # Bernoulli PDF formula
    return p**x * (1 - p)**(1 - x)

# Example usage:
p = 0.7  # Probability of success
x = 1    # Outcome (0 or 1)

# Calculate the probability for the given outcome
prob = bernoulli_pdf(p, x)
print(f"The probability P(X = {x}) is: {prob}")
# Out:
# The probability P(X = 1) is: 0.7

# %% [markdown]
# 4 Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10  # number of trials
p = 0.5  # probability of success
size = 1000  # number of experiments (samples)

# Simulate binomial distribution using numpy
binomial_data = np.random.binomial(n, p, size)

# Plot the histogram of the simulated data
plt.hist(binomial_data, bins=np.arange(n + 2) - 0.5, edgecolor='black', density=True)

# Add labels and title
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution: n={n}, p={p}')

# Show the plot
plt.xticks(np.arange(n + 1))  # Set x-ticks to range from 0 to n
plt.show()

# %% [markdown]
# 5 Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Poisson distribution
lambda_poisson = 3  # The average rate (lambda) of occurrences
size = 1000  # Number of samples

# Generate Poisson-distributed data
poisson_data = np.random.poisson(lambda_poisson, size)

# Plot the histogram of the Poisson distribution
plt.hist(poisson_data, bins=range(0, max(poisson_data) + 1), edgecolor='black', density=True)

# Add labels and title
plt.xlabel('Number of occurrences')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution: λ={lambda_poisson}')

# Show the plot
plt.xticks(np.arange(0, max(poisson_data) + 1))  # Set x-ticks to the range of possible occurrences
plt.show()

# %% [markdown]
# 6 Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the discrete uniform distribution
low = 1  # lowest value
high = 6  # highest value

# Generate possible outcomes
x = np.arange(low, high + 1)

# The probability of each outcome (uniform distribution)
probabilities = np.ones_like(x) / len(x)

# Calculate the cumulative distribution function (CDF)
cdf = np.cumsum(probabilities)

# Plot the CDF
plt.step(x, cdf, where='post', color='skyblue', linestyle='-', linewidth=2)

# Add labels and title
plt.xlabel('Outcome')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of Discrete Uniform Distribution')

# Show the plot
plt.xticks(x)  # Set x-ticks to match the outcomes
plt.yticks(np.arange(0, 1.1, 0.1))  # Set y-ticks for cumulative probability from 0 to 1
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 7 Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the continuous uniform distribution
low = 0    # lower bound of the distribution
high = 10  # upper bound of the distribution
size = 10000  # number of random samples to generate

# Generate random samples from the continuous uniform distribution
uniform_data = np.random.uniform(low, high, size)

# Plot the histogram of the data to approximate the PDF
plt.hist(uniform_data, bins=30, density=True, alpha=0.7)
plt.show()

# %% [markdown]
# 8  Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mean = 0     # Mean (mu)
std_dev = 1  # Standard deviation (sigma)
size = 10000 # Number of samples

# Generate random samples from a normal distribution
normal_data = np.random.normal(mean, std_dev, size)

# Plot the histogram of the normal distribution
plt.hist(normal_data, bins=30, density=True, alpha=0.7, color='skyblue', edgecolor='black')

# Plot the theoretical PDF of the normal distribution
x = np.linspace(min(normal_data), max(normal_data), 1000)
pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev)**2)
plt.plot(x, pdf, color='red', linestyle='--', label='Theoretical PDF')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Simulated Normal Distribution')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 9 Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    """
    Calculate the Z-scores for a given dataset.

    Parameters:
    data (array-like): The dataset for which Z-scores will be calculated.

    Returns:
    array: The Z-scores of the dataset.
    """
    mean = np.mean(data)   # Calculate the mean
    std_dev = np.std(data) # Calculate the standard deviation
    z_scores = (data - mean) / std_dev  # Apply the Z-score formula
    return z_scores

def plot_z_scores(data):
    """
    Plot the Z-scores of a dataset.

    Parameters:
    data (array-like): The dataset to calculate and plot Z-scores.
    """
    # Calculate Z-scores
    z_scores = calculate_z_scores(data)

    # Plot the Z-scores
    plt.plot(z_scores, marker='o', linestyle='-', color='b', label='Z-scores')
    plt.axhline(0, color='black', linewidth=1, linestyle='--', label='Mean (Z=0)')

    # Add labels and title
    plt.xlabel('Index')
    plt.ylabel('Z-score')
    plt.title('Z-scores of the Dataset')
    plt.legend()

    # Show the plot
    plt.show()

# Example usage:
data = [10, 20, 15, 25, 30, 35, 40, 45, 50, 60]  # Example dataset
plot_z_scores(data)

# %% [markdown]
# 10 Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

def central_limit_theorem(sample_size, num_samples, dist_low, dist_high):
    """
    Implements the Central Limit Theorem for a non-normal distribution (Uniform in this case).

    Parameters:
    sample_size (int): The size of each sample.
    num_samples (int): The number of samples to take.
    dist_low (float): The lower bound of the uniform distribution.
    dist_high (float): The upper bound of the uniform distribution.

    Returns:
    sample_means (array): The means of the samples.
    """
    # Generate random data from a uniform distribution
    uniform_data = np.random.uniform(dist_low, dist_high, (num_samples, sample_size))

    # Calculate the means of each sample
    sample_means = np.mean(uniform_data, axis=1)

    return sample_means

# Parameters
sample_size = 30  # Size of each sample
num_samples = 1000  # Number of samples to take
dist_low = 0  # Lower bound for uniform distribution
dist_high = 10  # Upper bound for uniform distribution

# Generate sample means using CLT
sample_means = central_limit_theorem(sample_size, num_samples, dist_low, dist_high)

# Plot the distribution of the sample means
plt.hist(sample_means, bins=30, density=True, alpha=0.7, color='skyblue', edgecolor='black')

# Plot the theoretical normal distribution for comparison
mean = np.mean(sample_means)
std_dev = np.std(sample_means)
x = np.linspace(min(sample_means), max(sample_means), 1000)
pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)
plt.plot(x, pdf, color='red', linestyle='--', label='Theoretical Normal PDF')

# Add labels and title
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.title('Central Limit Theorem for a Uniform Distribution')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 11 Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

def central_limit_theorem_normal(sample_size, num_samples, mean, std_dev):
    """
    Simulates the Central Limit Theorem for a normal distribution.

    Parameters:
    sample_size (int): The size of each sample.
    num_samples (int): The number of samples to take.
    mean (float): The mean of the normal distribution.
    std_dev (float): The standard deviation of the normal distribution.

    Returns:
    sample_means (array): The means of the samples.
    """
    # Generate random data from a normal distribution
    normal_data = np.random.normal(mean, std_dev, (num_samples, sample_size))

    # Calculate the means of each sample
    sample_means = np.mean(normal_data, axis=1)

    return sample_means

# Parameters for the normal distribution
mean = 50        # Mean of the normal distribution
std_dev = 10     # Standard deviation of the normal distribution
sample_size = 30 # Size of each sample
num_samples = 1000 # Number of samples to take

# Generate sample means using CLT
sample_means = central_limit_theorem_normal(sample_size, num_samples, mean, std_dev)

# Plot the distribution of the sample means
plt.hist(sample_means, bins=30, density=True, alpha=0.7, color='skyblue', edgecolor='black')

# Plot the theoretical normal distribution for comparison
x = np.linspace(min(sample_means), max(sample_means), 1000)
pdf = (1 / (std_dev / np.sqrt(sample_size) * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / (std_dev / np.sqrt(sample_size)))**2)
plt.plot(x, pdf, color='red', linestyle='--', label='Theoretical Normal PDF')

# Add labels and title
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.title('Central Limit Theorem for a Normal Distribution')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 12 Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Calculates and plots the standard normal distribution (mean = 0, std = 1).
    """
    # Define the range of x values (from -4 to 4 for a typical standard normal distribution)
    x = np.linspace(-4, 4, 1000)

    # Calculate the probability density function (PDF) of the standard normal distribution
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot the standard normal distribution
    plt.plot(x, pdf, color='blue', label='Standard Normal Distribution (mean=0, std=1)')

    # Add labels and title
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.axhline(0, color='black',linewidth=1)
    plt.axvline(0, color='black',linewidth=1)
    plt.legend()

    # Show the plot
    plt.show()

# Call the function to plot the standard normal distribution
plot_standard_normal_distribution()

# %% [markdown]
# 13 Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

def generate_binomial_distribution(n, p, size):
    """
    Generates random variables from a binomial distribution and calculates their probabilities.

    Parameters:
    n (int): Number of trials.
    p (float): Probability of success on each trial.
    size (int): Number of random variables to generate.

    Returns:
    random_variables (array): Generated random variables.
    probabilities (array): Corresponding probabilities for each random variable.
    """
    # Generate random variables from a binomial distribution
    random_variables = np.random.binomial(n, p, size)

    # Calculate the corresponding probabilities (PMF) for each random variable
    probabilities = binom.pmf(random_variables, n, p)

    return random_variables, probabilities

# Parameters for the binomial distribution
n = 10      # Number of trials
p = 0.5     # Probability of success on each trial
size = 1000 # Number of random variables to generate

# Generate random variables and calculate probabilities
random_variables, probabilities = generate_binomial_distribution(n, p, size)

# Plot histogram of the generated random variables
plt.hist(random_variables, bins=np.arange(n+2) - 0.5, density=True, alpha=0.7, color='skyblue', edgecolor='black')

# Plot the theoretical binomial distribution for comparison
x = np.arange(0, n+1)
pmf_values = binom.pmf(x, n, p)
plt.plot(x, pmf_values, 'ro', label='Binomial PMF', markersize=10)

# Add labels and title
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.legend()

# Show the plot
plt.show()

# Print some of the random variables and their probabilities for verification
print("Random Variables:", random_variables[:10])  # Show first 10 random variables
print("Corresponding Probabilities:", probabilities[:10])  # Show first 10 probabilities
# Out:
# Random Variables: [6 3 3 7 6 5 4 6 3 6]
# Corresponding Probabilities: [0.20507812 0.1171875  0.1171875  0.1171875  0.20507812 0.24609375
#  0.20507812 0.20507812 0.1171875  0.20507812]

# %% [markdown]
# 14 Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, mean, std_dev):
    """
    Calculates the Z-score for a given data point.

    Parameters:
    data_point (float): The data point whose Z-score needs to be calculated.
    mean (float): The mean of the distribution.
    std_dev (float): The standard deviation of the distribution.

    Returns:
    float: The Z-score for the given data point.
    """
    z_score = (data_point - mean) / std_dev
    return z_score

def plot_standard_normal_distribution(z_score):
    """
    Plots the standard normal distribution and marks the Z-score.

    Parameters:
    z_score (float): The Z-score to be marked on the plot.
    """
    # Generate x values for the standard normal distribution
    x = np.linspace(-4, 4, 1000)

    # Calculate the probability density function (PDF) of the standard normal distribution
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot the standard normal distribution
    plt.plot(x, pdf, color='blue', label='Standard Normal Distribution (mean=0, std=1)')

    # Mark the Z-score on the plot
    plt.axvline(x=z_score, color='red', linestyle='--', label=f'Z-score = {z_score:.2f}')

    # Add labels and title
    plt.xlabel('Z')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution with Z-score')
    plt.legend()

    # Show the plot
    plt.show()

# Parameters for the distribution
mean = 50     # Mean of the distribution
std_dev = 10  # Standard deviation of the distribution

# Data point
data_point = 60  # The data point to calculate the Z-score for

# Calculate the Z-score
z_score = calculate_z_score(data_point, mean, std_dev)

# Print the Z-score
print(f"The Z-score for the data point {data_point} is: {z_score:.2f}")

# Plot the standard normal distribution and mark the Z-score
plot_standard_normal_distribution(z_score)
# Out:
# The Z-score for the data point 60 is: 1.00

# %% [markdown]
# 15 Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

def hypothesis_testing_z(sample_data, population_mean, population_std, alpha=0.05):
    """
    Performs hypothesis testing using Z-statistics for a given sample data.

    Parameters:
    sample_data (array): Sample data for the hypothesis test.
    population_mean (float): The population mean under the null hypothesis (mu_0).
    population_std (float): The population standard deviation (sigma).
    alpha (float): The significance level (default is 0.05).

    Returns:
    str: Result of the hypothesis test.
    """
    # Calculate the sample mean and sample size
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    # Calculate the Z-statistic
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Calculate the critical value for a two-tailed test
    z_critical = norm.ppf(1 - alpha / 2)  # For two-tailed test, alpha/2 on both sides

    # Compare the Z-statistic with the critical value
    if abs(z_statistic) > z_critical:
        return f"Reject the null hypothesis. Z-statistic = {z_statistic:.2f}, Critical Z = {z_critical:.2f}"
    else:
        return f"Fail to reject the null hypothesis. Z-statistic = {z_statistic:.2f}, Critical Z = {z_critical:.2f}"

# Sample dataset
sample_data = [52, 53, 54, 50, 49, 51, 53, 56, 55, 52]

# Population parameters
population_mean = 50     # The population mean under the null hypothesis
population_std = 5      # Population standard deviation

# Perform hypothesis testing
result = hypothesis_testing_z(sample_data, population_mean, population_std, alpha=0.05)

# Output the result of the hypothesis test
print(result)
# Out:
# Fail to reject the null hypothesis. Z-statistic = 1.58, Critical Z = 1.96

# %% [markdown]
# 16 Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
import scipy.stats as stats

def confidence_interval(sample_data, confidence_level=0.95):
    """
    Calculates the confidence interval for a given sample dataset.

    Parameters:
    sample_data (array): The sample data for which the confidence interval is to be calculated.
    confidence_level (float): The desired confidence level (default is 95%).

    Returns:
    tuple: The lower and upper bounds of the confidence interval.
    """
    # Sample statistics
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)  # Use ddof=1 for sample standard deviation
    sample_size = len(sample_data)

    # Critical value (z-value) from the Z-distribution for the confidence level
    z_critical = stats.norm.ppf(1 - (1 - confidence_level) / 2)

    # Margin of error
    margin_of_error = z_critical * (sample_std / np.sqrt(sample_size))

    # Confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Example dataset
sample_data = [52, 53, 54, 50, 49, 51, 53, 56, 55, 52]

# Calculate the confidence interval
lower, upper = confidence_interval(sample_data, confidence_level=0.95)

# Output the result
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 95% Confidence Interval: (51.15, 53.85)

# %% [markdown]
# 17 Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
import scipy.stats as stats

def confidence_interval(sample_data, confidence_level=0.95):
    """
    Calculates the confidence interval for a given sample dataset.

    Parameters:
    sample_data (array): The sample data for which the confidence interval is to be calculated.
    confidence_level (float): The desired confidence level (default is 95%).

    Returns:
    tuple: The lower and upper bounds of the confidence interval.
    """
    # Sample statistics
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)  # Use ddof=1 for sample standard deviation
    sample_size = len(sample_data)

    # Critical value (z-value) from the Z-distribution for the confidence level
    z_critical = stats.norm.ppf(1 - (1 - confidence_level) / 2)

    # Margin of error
    margin_of_error = z_critical * (sample_std / np.sqrt(sample_size))

    # Confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Generate data from a normal distribution
np.random.seed(42)  # For reproducibility
mean = 50          # True population mean
std_dev = 10       # True population standard deviation
sample_size = 100  # Number of samples

sample_data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Calculate the confidence interval
lower, upper = confidence_interval(sample_data, confidence_level=0.95)

# Output the result
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 95% Confidence Interval: (47.18, 50.74)

# %% [markdown]
# 18 Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_normal_pdf(mu, sigma):
    """
    Calculate and plot the PDF of a normal distribution.

    Parameters:
    mu (float): The mean of the normal distribution.
    sigma (float): The standard deviation of the normal distribution.
    """
    # Generate a range of x values
    x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

    # Calculate the corresponding PDF values using scipy's norm.pdf
    pdf_values = stats.norm.pdf(x, mu, sigma)

    # Plot the PDF
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf_values, label=f'Normal Distribution\nMean = {mu}, Std = {sigma}', color='blue')
    plt.fill_between(x, pdf_values, color='skyblue', alpha=0.4)

    # Labels and title
    plt.title('Probability Density Function of a Normal Distribution')
    plt.xlabel('x')
    plt.ylabel('PDF')
    plt.legend(loc='best')
    plt.grid(True)

    # Show the plot
    plt.show()

# Parameters for the normal distribution
mu = 0      # Mean of the distribution
sigma = 1   # Standard deviation of the distribution

# Plot the normal PDF
plot_normal_pdf(mu, sigma)

# %% [markdown]
# 19  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_poisson_cdf(lmbda, max_k):
    """
    Plots the CDF of a Poisson distribution.

    Parameters:
    lmbda (float): The rate of occurrences (mean of the Poisson distribution).
    max_k (int): The maximum number of occurrences (k value) to consider for plotting the CDF.
    """
    # Generate a range of k values (number of occurrences)
    k_values = np.arange(0, max_k + 1)

    # Calculate the CDF values for each k
    cdf_values = stats.poisson.cdf(k_values, mu=lmbda)

    # Plot the CDF
    plt.figure(figsize=(8, 5))
    plt.step(k_values, cdf_values, where='post', label=f'Poisson Distribution\nλ = {lmbda}')
    plt.fill_between(k_values, cdf_values, color='skyblue', alpha=0.4)

    # Labels and title
    plt.title('Cumulative Distribution Function (CDF) of a Poisson Distribution')
    plt.xlabel('k (Number of occurrences)')
    plt.ylabel('CDF (P(X ≤ k))')
    plt.legend(loc='best')
    plt.grid(True)

    # Show the plot
    plt.show()

# Parameters for the Poisson distribution
lambda_value = 3   # Average rate of occurrences (λ)
max_k = 10         # Maximum value of k to plot

# Plot the Poisson CDF
plot_poisson_cdf(lambda_value, max_k)

# %% [markdown]
# 20 Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

# Define the parameters for the uniform distribution
a = 2  # Lower bound of the interval
b = 8  # Upper bound of the interval

# Simulate a random variable from the continuous uniform distribution
random_variable = np.random.uniform(a, b)

# Calculate the expected value (mean) of the continuous uniform distribution
expected_value = (a + b) / 2

# Output the result
print(f"Simulated random variable: {random_variable}")
print(f"Expected value of the distribution: {expected_value}")
# Out:
# Simulated random variable: 4.504466018892674
# Expected value of the distribution: 5.0

# %%
import numpy as np

def simulate_continuous_uniform(a, b, size=1000):
    """
    Simulate random variables from a continuous uniform distribution.

    Parameters:
    a (float): The lower bound of the uniform distribution.
    b (float): The upper bound of the uniform distribution.
    size (int): The number of random variables to generate.

    Returns:
    np.ndarray: The simulated random variables.
    """
    # Generate random variables from a uniform distribution
    random_variables = np.random.uniform(a, b, size)

    # Calculate the theoretical expected value for the uniform distribution
    expected_value = (a + b) / 2

    # Calculate the sample mean of the generated random variables
    sample_mean = np.mean(random_variables)

    return random_variables, expected_value, sample_mean

# Define the parameters for the uniform distribution
a = 0   # Lower bound
b = 10  # Upper bound

# Simulate the random variables and calculate expected value
random_variables, theoretical_expected_value, sample_mean = simulate_continuous_uniform(a, b)

# Output the results
print(f"Theoretical Expected Value (E(X)): {theoretical_expected_value}")
print(f"Sample Mean of Simulated Data: {sample_mean}")
# Out:
# Theoretical Expected Value (E(X)): 5.0
# Sample Mean of Simulated Data: 4.978590870452239

# %% [markdown]
# 21 Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

def compare_standard_deviations(dataset1, dataset2):
    """
    Compare the standard deviations of two datasets and visualize the difference.

    Parameters:
    dataset1 (array): The first dataset.
    dataset2 (array): The second dataset.
    """
    # Calculate the standard deviations of the datasets
    std1 = np.std(dataset1)
    std2 = np.std(dataset2)

    print(f"Standard Deviation of Dataset 1: {std1:.2f}")
    print(f"Standard Deviation of Dataset 2: {std2:.2f}")

    # Plot the histograms of the datasets for visualization
    plt.figure(figsize=(10, 6))

    # Plot histogram for dataset 1
    plt.hist(dataset1, bins=20, alpha=0.5, label=f"Dataset 1 (std={std1:.2f})", color='blue')

    # Plot histogram for dataset 2
    plt.hist(dataset2, bins=20, alpha=0.5, label=f"Dataset 2 (std={std2:.2f})", color='green')

    # Add labels and title
    plt.title('Comparison of Standard Deviations of Two Datasets')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend(loc='upper right')
    plt.grid(True)

    # Show the plot
    plt.show()

# Generate two sample datasets
np.random.seed(42)  # For reproducibility
dataset1 = np.random.normal(loc=50, scale=5, size=1000)  # Mean = 50, Std = 5
dataset2 = np.random.normal(loc=50, scale=10, size=1000)  # Mean = 50, Std = 10

# Compare the datasets
compare_standard_deviations(dataset1, dataset2)
# Out:
# Standard Deviation of Dataset 1: 4.89
# Standard Deviation of Dataset 2: 9.97

# %% [markdown]
# 22 Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np

def calculate_range_and_iqr(data):
    """
    Calculate the range and interquartile range (IQR) of a dataset.

    Parameters:
    data (array): The dataset.

    Returns:
    tuple: (range, IQR)
    """
    # Calculate the range (max - min)
    data_range = np.max(data) - np.min(data)

    # Calculate the interquartile range (IQR)
    Q1 = np.percentile(data, 25)  # 25th percentile
    Q3 = np.percentile(data, 75)  # 75th percentile
    IQR = Q3 - Q1

    return data_range, IQR

# Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean = 50, Std = 10

# Calculate the range and IQR
data_range, IQR = calculate_range_and_iqr(data)

# Output the results
print(f"Range of the dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {IQR:.2f}")
# Out:
# Range of the dataset: 70.94
# Interquartile Range (IQR) of the dataset: 12.96

# %% [markdown]
# 23 Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

def z_score_normalization(data):
    """
    Perform Z-score normalization on a dataset.

    Parameters:
    data (array): The dataset to be normalized.

    Returns:
    np.ndarray: The normalized dataset.
    """
    # Calculate the mean and standard deviation of the dataset
    mean = np.mean(data)
    std = np.std(data)

    # Apply Z-score normalization
    normalized_data = (data - mean) / std

    return normalized_data

# Generate a sample dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean = 50, Std = 10

# Normalize the dataset
normalized_data = z_score_normalization(data)

# Visualize the original and normalized datasets
plt.figure(figsize=(12, 6))

# Plot original data
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, alpha=0.7, color='blue')
plt.title('Original Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Plot normalized data
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, alpha=0.7, color='green')
plt.title('Normalized Data (Z-score)')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Output the mean and standard deviation of the normalized data
print(f"Mean of original data: {np.mean(data):.2f}")
print(f"Standard deviation of original data: {np.std(data):.2f}")
print(f"Mean of normalized data: {np.mean(normalized_data):.2f}")
print(f"Standard deviation of normalized data: {np.std(normalized_data):.2f}")
# Out:
# Mean of original data: 50.19
# Standard deviation of original data: 9.79
# Mean of normalized data: -0.00
# Standard deviation of normalized data: 1.00

# %% [markdown]
# 24  Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):
    """
    Calculate the skewness and kurtosis of a dataset.

    Parameters:
    data (array): The dataset.

    Returns:
    tuple: (skewness, kurtosis)
    """
    # Calculate skewness and kurtosis using scipy.stats functions
    data_skewness = skew(data)
    data_kurtosis = kurtosis(data)  # By default, this returns excess kurtosis

    return data_skewness, data_kurtosis

# Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=0, scale=1, size=1000)  # Mean = 0, Std = 1

# Calculate skewness and kurtosis
skewness, kurt = calculate_skewness_kurtosis(data)

# Output the results
print(f"Skewness of the dataset: {skewness:.3f}")
print(f"Kurtosis of the dataset: {kurt:.3f}")
# Out:
# Skewness of the dataset: 0.117
# Kurtosis of the dataset: 0.066
